# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Load dataset

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Matplotlib

# %% [markdown]
# # Scatter Plot

# %%
x_array = np.arange(0,10)
y_array = np.arange(11,21)

plt.figure(figsize=(5,7))
plt.scatter(x_array, y_array ,c ="b")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Graph")
plt.savefig("graph.png")

# %% [markdown]
# We can change the color of the points by using <i>c="".</i>
#
# Change the size of the figure using <i>plt.figure(figsize=(,)).</i>
#
# We can also save the figure using <i>plt.savefig("")</i>.

# %% [markdown]
# # Plot

# %%
plt.plot(x_array , y_array, "ro--") # o means dot,-- means dashed

# %% [markdown]
# # Creating Subplots

# %%
plt.subplot(2,2,1)
plt.plot(x_array, y_array, "ro--")
plt.subplot(2,2,2)
plt.scatter(x_array, y_array, c="b")
plt.subplot(2,2,3)
plt.plot(x_array, y_array, "g--")
plt.subplot(2,2,4)
plt.bar(x_array, y_array)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# # Creating a sine wave

# %%
pi = np.pi
x_1 = np.arange(0, 5 * pi, 0.1)
y_1 = np.sin(x_1)
plt.title("Sine wave")

plt.plot(x_1, y_1)

# %% [markdown]
# # Bar Plot

# %%
x_2 = [2,5,7,5,6]
y_2 = [5,2,4,5,8]
plt.barh(x_array, y_array, align = "center")
plt.barh(x_2, y_2, color="violet", align = "center")
plt.title("Bar Graph")
# Out:
# Text(0.5, 1.0, 'Bar Graph')

# %%
x_2 = [2,5,7,5,6]
y_2 = [5,2,4,5,8]
plt.bar(x_array, y_array, align = "center")
plt.bar(x_2, y_2, color="violet", align = "center")
plt.title("Bar Graph")
# Out:
# Text(0.5, 1.0, 'Bar Graph')

# %% [markdown]
# # Histogram

# %%
hist_array = np.array([12,43,5,5,6,76,67,5,78,56,67,21,57,65,6,56,23])
plt.hist(hist_array, bins= 20)
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# # Box Plot

# %%
boxplot_data = [np.random.normal(0, std, 100) for std in range(1,4)]
plt.boxplot(boxplot_data, vert = False, patch_artist = True);

# %% [markdown]
# # Pie Chart

# %%
labels = "BS Applied Physics","BS Chemistry","BS Psychology"
sizes = [11, 53, 204]
colors = ["gold", "lightcoral", "lightblue"]
explode = (0.5,0,0)

plt.pie(sizes, explode=explode, labels=labels, colors = colors, autopct = "%1.1f%%", shadow = True)
plt.axis("equal")
# Out:
# (-1.1288441844824257,
#  1.6208343802166236,
#  -1.105159412353171,
#  1.1050049211868136)

# %% [markdown]
# # Seaborn

# %% [markdown]
# # Distribution Plot

# %%
sns.distplot(df["sepal_length"]);
# Out:
# c:\users\mobal\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can remove the KDE (kernel density estimation) using:

# %%
sns.distplot(df["sepal_length"], kde = False);
# Out:
# c:\users\mobal\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can also manipulate the number of bins

# %%
sns.distplot(df["sepal_length"], kde = False, bins = 20)
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %% [markdown]
# # Joint Plot

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data = df)

# %% [markdown]
# We can add a regression line with:

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "reg")

# %% [markdown]
# We can also create a KDE plot

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "kde")

# %% [markdown]
# How about hexagon distribution

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "hex")

# %% [markdown]
# # KDE Plot

# %%
sns.kdeplot(df["petal_length"])
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df)

# %% [markdown]
# # Rug Plot

# %%
sns.rugplot(df["petal_width"])
# Out:
# <AxesSubplot:xlabel='petal_width'>

# %% [markdown]
# The sticks below shows the density of the values.

# %% [markdown]
# # Styling

# %% [markdown]
# We can play around to see what style fits our taste.

# %%
sns.set_style("whitegrid")
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "kde")

# %%
sns.set_style("dark")
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "hex")

# %%
sns.set_style("whitegrid")
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "reg")

# %% [markdown]
# We can edit other elements using:

# %%
sns.set_style("whitegrid")
sns.set_context("talk", font_scale = 1.2)
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "kde")

# %%
sns.set_style("whitegrid")
sns.set_context("poster", font_scale = 1.2)
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "kde")

# %%
sns.set_style("whitegrid")
sns.set_context("paper", font_scale = 1.2)
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "kde")

# %%
sns.set_style("ticks")
sns.set_context("paper", font_scale = 1.2)
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "reg")

# %%
sns.set_style("ticks")
sns.set_context("paper", font_scale = 1.2)
sns.jointplot(x="sepal_length", y="sepal_width", data = df, kind = "reg")
sns.despine(left = True, right = True , top = True , bottom= True)

# %% [markdown]
# # Categorical Data

# %% [markdown]
# Let's use another dataset with a categorical data

# %%
df2 = sns.load_dataset("tips")

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Bar Plot

# %%
sns.barplot(x = "sex", y = "total_bill", data=df2)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# We can add colors to categorical data using:

# %%
sns.pairplot(df2, hue = "sex", palette= "winter_r")

# %% [markdown]
# By default, the data above is aggregated based off of the mean.

# %% [markdown]
# We can change that using:

# %%
sns.barplot(x = "sex", y = "total_bill", data=df2, estimator=np.median)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # Count Plot

# %%
sns.countplot("sex", data = df2, saturation = 0.5);
# Out:
# c:\users\mobal\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Box Plot

# %%
sns.boxplot("smoker","total_bill", data = df2, palette= "winter_r", orient = "v");
# Out:
# c:\users\mobal\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x= "total_bill", y="day", hue = "smoker", data = df2)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x = "total_bill", y = "day", data = df2, palette = "winter_r")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# # Heat Maps

# %%
sepal_heatmap = np.array([df["sepal_length"], df["sepal_width"]])
ax = sns.heatmap(sepal_heatmap)

# %%
uniform_data = np.random.rand(10, 5)
ax = sns.heatmap(uniform_data)

# %% [markdown]
# # 3D Plots

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
sns.set_style("whitegrid", {"axes.grid" : False})
fig = plt.figure(figsize=(6,6))

ax = Axes3D(fig)
x = np.random.uniform(1,20,size=500)
y = np.random.uniform(1,100,size=500)
z = np.random.uniform(1,100,size=500)


ax.scatter(x, y, z, c=x, marker="o", edgecolors = "g")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_title("Scatter 3D")
# Out:
# Text(0.5, 0.92, 'Scatter 3D')

# %%
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

zline = np.linspace(0, 20, 200)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, "black")
ax.set_title("Plot 3D")

zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

ax.contour3D(X, Y, Z, 100, cmap ="bone")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.set_title("Contour Plot 3D");

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

ax.contour3D(X, Y, Z, 100, cmap ="icefire")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

ax.plot_wireframe(X, Y, Z, color="w")
ax.set_title("Wireframe");

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

ax.contour3D(X, Y, Z, 100, cmap ="icefire")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

ax.view_init(60, 30)
# Change view

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

ax.contour3D(X, Y, Z, 100, cmap ="icefire")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('Surface');

# %% [markdown]
# # Mobius Strip

# %%
from matplotlib.tri import Triangulation

theta = np.linspace(0, 2 * np.pi, 30)
w = np.linspace(-0.25, 0.25, 8)
w, theta = np.meshgrid(w, theta)
phi = 0.5 * theta

r = 1 + w * np.cos(phi)
x = np.ravel(r * np.cos(theta))
y = np.ravel(r * np.sin(theta))
z = np.ravel(w * np.sin(phi))


tri = Triangulation(np.ravel(w), np.ravel(theta))

fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)
ax.plot_trisurf(x, y, z, triangles=tri.triangles,
                cmap="cubehelix", linewidths=0.2);

ax.set_xlim(-1, 1); ax.set_ylim(-1, 1); ax.set_zlim(-1, 1);
